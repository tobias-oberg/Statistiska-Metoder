# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
Auto = pd.read_csv("Auto.csv")
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
# a) Which of the predictors are quantitative(numerical) and which are qualitative(categorial)? 

print(Auto.dtypes)

quantitative = []
qualitative = []

for col in Auto.columns:
    if Auto[col].dtype in ["int64", "float64"]:
        quantitative.append(col)
    else:
        qualitative.append(col)

print("Quantitative predictors:", quantitative)
print("Qualitative predictiors:", qualitative)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object
# Quantitative predictors: ['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'year', 'origin']
# Qualitative predictiors: ['horsepower', 'name']

# %%
# b) What is the range of each quantitative predictor? You can answer this using the min() and max() methods in numpy.

print("The range of each quantitative predictor:")
for col in quantitative:
    min_value = np.min(Auto[col])
    max_value = np.max(Auto[col])
    print(f"{col}: Min: {min_value}, Max: {max_value}, Range: {max_value - min_value}")
# Out:
# The range of each quantitative predictor:
# mpg: Min: 9.0, Max: 46.6, Range: 37.6
# cylinders: Min: 3, Max: 8, Range: 5
# displacement: Min: 68.0, Max: 455.0, Range: 387.0
# weight: Min: 1613, Max: 5140, Range: 3527
# acceleration: Min: 8.0, Max: 24.8, Range: 16.8
# year: Min: 70, Max: 82, Range: 12
# origin: Min: 1, Max: 3, Range: 2

# %%
# c) What is the mean and standard deviation of each quantitative predictor?

print("The mean and standard deviation of each quantitative predictor:")
for col in quantitative:
    mean_value = np.mean(Auto[col])
    standard_deviation = np.std(Auto[col])
    print(f"{col}: Mean value: {mean_value:.2f}, Standard deviation: {standard_deviation:.2f}")
# Out:
# The mean and standard deviation of each quantitative predictor:
# mpg: Mean value: 23.52, Standard deviation: 7.82
# cylinders: Mean value: 5.46, Standard deviation: 1.70
# displacement: Mean value: 193.53, Standard deviation: 104.25
# weight: Mean value: 2970.26, Standard deviation: 846.84
# acceleration: Mean value: 15.56, Standard deviation: 2.75
# year: Mean value: 75.99, Standard deviation: 3.69
# origin: Mean value: 1.57, Standard deviation: 0.80

# %%
# d) Now remove the 10th through 85th observations. 
# What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

Auto_filtered = Auto.drop(index=range(9,85))
for col in quantitative:
    min_value = np.min(Auto_filtered[col])
    max_value = np.max(Auto_filtered[col])
    mean_value = np.mean(Auto_filtered[col])
    standard_deviation = np.std(Auto_filtered[col])
    print(f"{col}: Range: {max_value - min_value}, Mean: {mean_value:.2f}, Standard deviation: {standard_deviation:.2f}")
# Out:
# mpg: Range: 35.6, Mean: 24.44, Standard deviation: 7.90
# cylinders: Range: 5, Mean: 5.37, Standard deviation: 1.65
# displacement: Range: 387.0, Mean: 187.05, Standard deviation: 99.48
# weight: Range: 3348, Mean: 2933.96, Standard deviation: 809.38
# acceleration: Range: 16.3, Mean: 15.72, Standard deviation: 2.68
# year: Range: 12, Mean: 77.15, Standard deviation: 3.11
# origin: Range: 2, Mean: 1.60, Standard deviation: 0.81

# %%
# e) Using the full data set, investigate the predictors graphically,using scatterplots or other tools of your choice. 
# Create some plots highlighting the relationships among the predictors. 
# Comment on your findings.
plt.figure(figsize=(8,5))
plt.scatter(Auto["weight"], Auto["mpg"], alpha=0.5,)
plt.title("Weight vs mpg")
plt.xlabel("Weight")
plt.ylabel("miles per gallon")
plt.grid(True)
plt.show()

# %%
# f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. 
# Do your plots suggest that any of the other variables might be useful in predicting mpg? 
# Justify your answer.
